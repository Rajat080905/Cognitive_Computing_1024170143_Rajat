# %% [markdown]
# 1.1

# %%
i=1
while i <= 3:
	print ("Rajat")
	i = i+1
# Out:
# Rajat
# Rajat
# Rajat

# %% [markdown]
# 2.1

# %%
x = 200
y = 300
z = 100
k = x+y+z
print(x,"+",y,"+",z,"=",k)
# Out:
# 200 + 300 + 100 = 600

# %% [markdown]
# 2.2

# %%
x = " i"
y = " am"
z = " Rajat"
k = k = x+y+z
print(x,"+",y,"+",z,"=",k)
# Out:
#  i +  am +  Rajat =  i am Rajat

# %% [markdown]
# 4.1

# %%
for i in range(1,11):
	print ( i * 7)

print()

for i in range(1,11):
  print (i * 9)
# Out:
# 7
# 14
# 21
# 28
# 35
# 42
# 49
# 56
# 63
# 70
#
# 9
# 18
# 27
# 36
# 45
# 54
# 63
# 72
# 81
# 90

# %% [markdown]
# 4.2

# %%
n = int(input("Enter a number 'n' : "))
for i in range(1,11):
  print(i*n)
# Out:
# Enter a number 'n' : 3
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30

# %% [markdown]
# 4.3

# %%
n = int(input("Enter a number 'n' : "))
total_sum = 0
for i in range(1, n + 1):
	total_sum = total_sum + i
print ("Sum : ", total_sum)
# Out:
# Enter a number 'n' : 5
# Sum :  15

# %% [markdown]
# 5.1

# %%
a = int(input("Enter the first number: "))
b = int(input("Enter the second number: "))
c = int(input("Enter the third number: "))


max = max(a, b, c)


print("The maximum number among", a, ",", b, ", and", c, "is:", max)
# Out:
# Enter the first number: 4
# Enter the second number: 5
# Enter the third number: 6
# The maximum number among 4 , 5 , and 6 is: 6

# %% [markdown]
# 5.2

# %%
n = int(input("Enter a number 'n' : "))
Sum_Divisible = 0
for i in range(1, n + 1):
    if i % 7 == 0 and i % 9 == 0:
        Sum_Divisible = Sum_Divisible + i
print("The sum of numbers divisible by 7 and 9 from 1 to", n, "is:", Sum_Divisible)
# Out:
# Enter a number 'n' : 99
# The sum of numbers divisible by 7 and 9 from 1 to 99 is: 63

# %% [markdown]
# 5.3

# %%
n = int(input("Enter a number 'n': "))
Prime_Sum = 0

for num in range(2, n + 1):
    prime = True
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            prime = False
            break
    if prime:
        Prime_Sum = Prime_Sum + num

print("The sum of prime numbers from 1 to", n, "is:", Prime_Sum)
# Out:
# Enter a number 'n': 9
# The sum of prime numbers from 1 to 9 is: 17

# %% [markdown]
# 6.1

# %%
def odd_number_sum(n):
    odd_sum = 0
    for i in range(1, n + 1):
        if i % 2 != 0:
            odd_sum = odd_sum + i
    return odd_sum

n = int(input("Enter a number 'n': "))
result = odd_number_sum(n)
print("The sum of odd numbers from 1 to", n, "is:", result)
# Out:
# Enter a number 'n': 5
# The sum of odd numbers from 1 to 5 is: 9

# %% [markdown]
# 6.2

# %%
def prime_number_sum(n):
    prime_sum = 0
    for num in range(2, n + 1):
        prime = True
        if num < 2:
            is_prime = False
        else:
            for i in range(2, int(num**0.5) + 1):
                if num % i == 0:
                    prime = False
                    break
        if prime:
            prime_sum = prime_sum + num
    return prime_sum

n = int(input("Enter a number 'n': "))
result = prime_number_sum(n)
print("The sum of prime numbers from 1 to", n, "is:", result)
# Out:
# Enter a number 'n': 6
# The sum of prime numbers from 1 to 6 is: 10
